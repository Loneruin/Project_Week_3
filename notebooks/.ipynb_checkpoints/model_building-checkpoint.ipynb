# %% [markdown]
# Build a regression model.

# %%
import statsmodels.api as sm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
from scipy import stats

# %% [markdown]
# Provide model output and an interpretation of the results.

# %%
bike_poi = pd.read_csv('join_data_original.csv')

# %%
# drop categorical variables and keep numerical variables only
join_data = bike_poi.drop(columns = ['longitude', 'latitude','f_longitude','f_latitude','break_fast_True','brunch_False','brunch_True','lunch_True','dinner_False','dinner_True', 'happy_hour_False','happy_hour_True'])

# %%
#pairplot to take a look the data again
sns.pairplot(data=join_data)
plt.show()

# %%
# check corellations one more time
join_data.corr()
# Out:
#              distance    rating  popularity  empty_slots     bikes
# distance     1.000000  0.276580   -0.087390    -0.244986  0.238783
# rating       0.276580  1.000000    0.360671    -0.079130  0.274036
# popularity  -0.087390  0.360671    1.000000     0.132586 -0.053297
# empty_slots -0.244986 -0.079130    0.132586     1.000000 -0.451012
# bikes        0.238783  0.274036   -0.053297    -0.451012  1.000000

# %% [markdown]
# #### Simple Linear Regression

# %%
y = join_data['bikes']
X = join_data['rating']
X = sm.add_constant(X)
X.head()
# Out:
#    const  rating
# 0    1.0     7.3
# 1    1.0     8.7
# 2    1.0     8.5
# 3    1.0     7.5
# 4    1.0     7.0

# %%
model = sm.OLS(y, X) #instantiate
rating_bike_result = model.fit()
print(rating_bike_result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  bikes   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.056
# Method:                 Least Squares   F-statistic:                     3.897
# Date:                Sun, 29 Jan 2023   Prob (F-statistic):             0.0541
# Time:                        22:45:28   Log-Likelihood:                -211.63
# No. Observations:                  50   AIC:                             427.3
# Df Residuals:                      48   BIC:                             431.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -42.6220     29.217     -1.459      0.151    -101.366      16.122
# ...

# %% [markdown]
# #### Important Output:

# %% [markdown]
# - **R-squared**: R-squared reflects the fit of the model. R-squared values range from 0 to 1, where a higher value generally indicates a better fit. In this out put, we can see that the value is 0.075. This means that the model is capable of explaining 7.5% of the patterns in the data
# - **P>|t|**: A p-value of higher than 0.05 which means the rating of the restaurants does not have an impact the number of bikes
# - **coef**: Coef is short for the coefficient of the independent variable. It represents the impact on the response variable per unit increase of the independent variable. In this case, we can see that the coef of rating is 7.4924. This means that a unit increase in the value of rating will have a positive impact on the number of bikes

# %% [markdown]
# 1. Residual plots

# %%
residuals = rating_bike_result.resid
residuals
# Out:
# 0    -10.072813
# 1    -20.562226
# 2    -21.063739
# 3     -7.571301
# 4     -1.825082
# 5    -10.323569
# 6     -2.063739
# 7    -10.066764
# 8     -7.819032
# 9     -8.323569
# 10    -3.320544
# 11     8.927187
# 12    53.688530
# 13    13.673406
# 14    -9.323569
# 15    -3.317520
# 16     0.676431
# 17    -7.571301
# 18    13.936261
# 19    -7.822057
# 20   -15.317520
# 21    10.174918
# 22    -4.825082
# 23     1.930212
# 24   -10.812983
# 25   -14.063739
# 26     0.180968
# 27     5.936261
# 28    -2.565251
# 29    52.183993
# 30    -1.320544
# 31    -3.069788
# 32    12.679456
# 33    -4.069788
# 34    -8.069788
# 35    10.924162
# 36    12.673406
# 37    -3.326594
# 38    -8.825082
# 39    -8.323569
# 40    -9.571301
# 41   -21.060714
# 42    -7.075838
# 43     5.171894
# 44     3.930212
# 45    -8.568276
# 46   -19.562226
# 47    -9.072813
# 48    33.673406
# 49    50.187017
# dtype: float64

# %% [markdown]
# 2. Normality
#
# Check the normality assumption by checking normality on the residuals

# %%
sns.histplot(residuals)
plt.show()

# %%
sns.scatterplot(data = join_data, x='rating', y='bikes')
plt.show()

# %%
sm.qqplot(residuals)
plt.show()

# %%
scipy.stats.shapiro(residuals)
# Out:
# ShapiroResult(statistic=0.7965397238731384, pvalue=7.304063842639152e-07)

# %% [markdown]
# Normality assumption seems to be violated. It seems it was likely due to outliers

# %% [markdown]
# 3. Homoscedasticity

# %%
ax = sns.scatterplot(x=join_data['rating'], y=residuals)
ax.axhline(0)

# %%
# Use the Breusch-Pagan test to formally test homoscedasticity
stat, p, f_stat, f_p = sm.stats.diagnostic.het_breuschpagan(residuals,results.model.exog)
print(p,f_p)
# Out:
# 1.3488974466368023e-09 1.939137094603601e-15

# %% [markdown]
# Homoscedascity assumption is not satisfied

# %% [markdown]
# # Stretch

# %% [markdown]
# How can you turn the regression model into a classification model?
